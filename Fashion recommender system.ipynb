# %%
#importing tensorflow
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input

# %%
#modifyig model
model = ResNet50(weights='imagenet', include_top=False,input_shape=(224,224,3))
model.trainable=False

# %%
model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
# ...
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# _________________________________________________________________
# None

# %%
#Create function for preprocessing and normalizing image features

# %%
import numpy as np
from numpy.linalg import norm
import os
def extract_features(img_path,model):
    img = image.load_img(img_path,target_size=(224,224))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array,axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocessed_img).flatten()
    normalized_result = result/norm(result)
    
    return normalized_result

# %%
#Features extraction

# %%
from tqdm import tqdm
filenames =[]
for file in os.listdir('F:/fashion-dataset/Data'):
    filenames.append(os.path.join('F:/fashion-dataset/Data',file))

feature_list = []

for file in tqdm(filenames):
    feature_list.append(extract_features(file,model))
    
print(np.array(feature_list).shape)
# Out:
# ...
#   5%|▌         | 453/9011 [04:49<1:21:08,  1.76it/s]
# ...
# ...
# 100%|██████████| 9011/9011 [1:45:44<00:00,  1.42it/s]
# (9011, 2048)

# %%
#exporting features

# %%
import pickle
pickle.dump(feature_list,open('embeddings.pkl','wb'))
pickle.dump(filenames,open('filenames.pkl','wb'))

# %%
feature_list = pickle.load(open('embeddings.pkl','rb'))
print(np.array(feature_list).shape)
# Out:
# (9011, 2048)

# %%
filenames = pickle.load(open('filenames.pkl','rb'))

# %%
from sklearn.neighbors import NearestNeighbors
import cv2

# %%
feature_list = np.array(pickle.load(open('embeddings.pkl','rb')))
filenames = pickle.load(open('filenames.pkl','rb'))

# %%
img = image.load_img('F:/fashion-dataset/Test/3975.jpg',target_size=(224,224))
img_array = image.img_to_array(img)
expanded_img_array = np.expand_dims(img_array, axis=0)
preprocessed_img = preprocess_input(expanded_img_array)
result = model.predict(preprocessed_img).flatten()
normalized_result = result / norm(result)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
print(img_array)
img_array.shape
# Out:
# [[[72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   ...
#   [71.32  75.221 83.061]
#   [71.32  75.221 83.061]
#   [71.32  75.221 83.061]]
#
#  [[72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   ...
#   [72.32  76.221 84.061]
#   [71.32  75.221 83.061]
#   [71.32  75.221 83.061]]
#
#  [[72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   ...
#   [72.32  76.221 84.061]
#   [72.32  76.221 84.061]
#   [71.32  75.221 83.061]]
#
#  ...
#
#  [[68.32  72.221 80.061]
#   [68.32  72.221 80.061]
#   [67.32  71.221 79.061]
#   ...
#   [71.32  75.221 83.061]
#   [70.32  74.221 82.061]
#   [71.32  75.221 83.061]]
#
#  [[68.32  72.221 80.061]
#   [68.32  72.221 80.061]
#   [68.32  72.221 80.061]
#   ...
#   [71.32  75.221 83.061]
#   [71.32  75.221 83.061]
#   [71.32  75.221 83.061]]
#
#  [[68.32  72.221 80.061]
#   [68.32  72.221 80.061]
#   [67.32  71.221 79.061]
#   ...
#   [71.32  75.221 83.061]
# ...

# %%
print(expanded_img_array)
print(expanded_img_array.shape)
# Out:
# [[[[72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    ...
#    [71.32  75.221 83.061]
#    [71.32  75.221 83.061]
#    [71.32  75.221 83.061]]
#
#   [[72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    ...
#    [72.32  76.221 84.061]
#    [71.32  75.221 83.061]
#    [71.32  75.221 83.061]]
#
#   [[72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    ...
#    [72.32  76.221 84.061]
#    [72.32  76.221 84.061]
#    [71.32  75.221 83.061]]
#
#   ...
#
#   [[68.32  72.221 80.061]
#    [68.32  72.221 80.061]
#    [67.32  71.221 79.061]
#    ...
#    [71.32  75.221 83.061]
#    [70.32  74.221 82.061]
#    [71.32  75.221 83.061]]
#
#   [[68.32  72.221 80.061]
#    [68.32  72.221 80.061]
#    [68.32  72.221 80.061]
#    ...
#    [71.32  75.221 83.061]
#    [71.32  75.221 83.061]
#    [71.32  75.221 83.061]]
#
#   [[68.32  72.221 80.061]
#    [68.32  72.221 80.061]
#    [67.32  71.221 79.061]
# ...

# %%
print(preprocessed_img)
print(preprocessed_img.flatten().shape)
# Out:
# [[[[84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    ...
#    [83.061 75.221 71.32 ]
#    [83.061 75.221 71.32 ]
#    [83.061 75.221 71.32 ]]
#
#   [[84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    ...
#    [84.061 76.221 72.32 ]
#    [83.061 75.221 71.32 ]
#    [83.061 75.221 71.32 ]]
#
#   [[84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    ...
#    [84.061 76.221 72.32 ]
#    [84.061 76.221 72.32 ]
#    [83.061 75.221 71.32 ]]
#
#   ...
#
#   [[80.061 72.221 68.32 ]
#    [80.061 72.221 68.32 ]
#    [79.061 71.221 67.32 ]
#    ...
#    [83.061 75.221 71.32 ]
#    [82.061 74.221 70.32 ]
#    [83.061 75.221 71.32 ]]
#
#   [[80.061 72.221 68.32 ]
#    [80.061 72.221 68.32 ]
#    [80.061 72.221 68.32 ]
#    ...
#    [83.061 75.221 71.32 ]
#    [83.061 75.221 71.32 ]
#    [83.061 75.221 71.32 ]]
#
#   [[80.061 72.221 68.32 ]
#    [80.061 72.221 68.32 ]
#    [79.061 71.221 67.32 ]
# ...

# %%
#using NearestNeighbour to get the similar images

# %%
neighbors = NearestNeighbors(n_neighbors=6,algorithm='brute',metric='euclidean')
neighbors.fit(feature_list)

distances,indices = neighbors.kneighbors([normalized_result])

print(indices)

for file in indices[0][1:5]:
    temp_img = cv2.imread(filenames[file])
    cv2.imshow('output',cv2.resize(temp_img,(512,512)))
    cv2.waitKey(0)
# Out:
# [[5864 5862 5863 5855 2901 5841]]
